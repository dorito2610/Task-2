# %% [markdown]
# ## Task-2:
# <font color="darkorange">
# <u>WORKING</u>:
# Make a color detection system with the help of Pandas and
# Open CV based on the provided dataset.
#
# <u>Dataset</u>: https://github.com/codebrainz/color-names/blob/master/output/colors.csv
#
# <u>Language</u>: Python

# %% [markdown]
# ### Objective: Detecting the color in the selected image

# %% [markdown]
# ##### Reading the csv file and jpg

# %%
import pandas as pd
import cv2

# %%
dataframe=pd.read_csv("colors.csv")
dataframe
# Out:
#        air_force_blue_raf   Air Force Blue (Raf)  #5d8aa8   93  138  168
# 0     air_force_blue_usaf  Air Force Blue (Usaf)  #00308f    0   48  143
# 1    air_superiority_blue   Air Superiority Blue  #72a0c1  114  160  193
# 2         alabama_crimson        Alabama Crimson  #a32638  163   38   56
# 3              alice_blue             Alice Blue  #f0f8ff  240  248  255
# 4        alizarin_crimson       Alizarin Crimson  #e32636  227   38   54
# ..                    ...                    ...      ...  ...  ...  ...
# 859         yellow_orange          Yellow Orange  #ffae42  255  174   66
# 860        yellow_process       Yellow (Process)  #ffef00  255  239    0
# 861            yellow_ryb           Yellow (Ryb)  #fefe33  254  254   51
# 862                zaffre                 Zaffre  #0014a8    0   20  168
# 863     zinnwaldite_brown      Zinnwaldite Brown  #2c1608   44   22    8
#
# [864 rows x 6 columns]

# %%
img_path=r"C:\sarath\DevStack\Task 2\Task-2\colors.png"
image=cv2.imread(img_path)

# %% [markdown]
# ### Indexing the dataframe

# %%
dataframe=pd.read_csv("colors.csv",names=["color","name","HEX value","R","G","B"],header=None)
dataframe
# Out:
#                     color                   name HEX value    R    G    B
# 0      air_force_blue_raf   Air Force Blue (Raf)   #5d8aa8   93  138  168
# 1     air_force_blue_usaf  Air Force Blue (Usaf)   #00308f    0   48  143
# 2    air_superiority_blue   Air Superiority Blue   #72a0c1  114  160  193
# 3         alabama_crimson        Alabama Crimson   #a32638  163   38   56
# 4              alice_blue             Alice Blue   #f0f8ff  240  248  255
# ..                    ...                    ...       ...  ...  ...  ...
# 860         yellow_orange          Yellow Orange   #ffae42  255  174   66
# 861        yellow_process       Yellow (Process)   #ffef00  255  239    0
# 862            yellow_ryb           Yellow (Ryb)   #fefe33  254  254   51
# 863                zaffre                 Zaffre   #0014a8    0   20  168
# 864     zinnwaldite_brown      Zinnwaldite Brown   #2c1608   44   22    8
#
# [865 rows x 6 columns]

# %% [markdown]
# ### Function to identify the colors

# %%
# Global variables
x=y=r=g=b=0
mouse_click=False

# %% [markdown]
# ##### We identify the colors by finding the matching color from the resultant array of RGB values

# %%
def color_name(R,G,B):
    minimum=10000 # treshhold value
    for i in range(len(dataframe)):
        rgb=abs(R - int(dataframe.loc[i,"R"]))+abs(G - int(dataframe.loc[i,"G"]))+abs(B - int(dataframe.loc[i,"B"]))
        if rgb<minimum:
            minimum=rgb
            color_name=dataframe.loc[i,"name"]
    return color_name

# %% [markdown]
# ### function to get the co-ordinates of the mouse click

# %%
def click(lclick,X,Y,flags,param):
    if lclick==cv2.EVENT_FLAG_LBUTTON: # single left click
        # opencv uses b,g,r format instead of rgb

        global b,g,r,x,y,mouse_click
        mouse_click=True
        x=X
        y=Y
        b,g,r=image[y,x]
        b=int(b)
        g=int(g)
        r=int(r)

# %% [markdown]
# #### Creating a window to display the input image and responding to the mouse click

# %%
cv2.namedWindow("image")
cv2.setMouseCallback("image",click)

# %%
while True:
    cv2.imshow("image",image)
    if mouse_click==True:
        cv2.rectangle(image,(20,20),(750,60),(255,255,255),-1)
        output=color_name(r,g,b)+"RGB values="+str(r)+" "+str(g)+" "+str(b)
        cv2.putText(image,output,(50,50),2,0.8,(0,0,0),2,cv2.LINE_AA)
    mouse_click=False

    #breaking loop when user presses esc key
    if cv2.waitKey(20) & 0xFF==27:
        break
cv2.destroyAllWindows()
